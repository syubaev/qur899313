# %% [markdown]
# # TF IDF
#
# Adding the term frequency inverse dictionary frequency measure (tf-idf). The term
# frequency is the count of a term in a specific question, the inverse document frequency is the log of the total number
# of questions divided by the number of questions containing the term.
#
# ### Steps
#
# 1. Load cleaned data
# 2. Count TF-IDF
#
# 'question1_lowercase' - low case questions with stop words
#
# 'concatenated_questions'='question1_lowercase'+
#                                     'question2_lowercase'
#
# CountVectorizer('concatenated_questions')
#
# Credit: Some of the code was inspired by this awesome [NLP repo][1].
#
#
#
#
#   [1]: https://github.com/rouseguy/DeepLearningNLP_Py

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
pd.set_option('max_colwidth', 250)
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
#from nltk import ngrams

#from sklearn import metrics
import xgboost as xgb
#from sklearn.linear_model import LogisticRegression

#from gensim.models import word2vec

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = (16,6)

import multiprocessing as mp

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from difflib import SequenceMatcher

from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss


# %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 16.3 ms

# %%
#data = pd.read_csv('data/train.csv').sample(50000, random_state=23)
train = pd.read_csv('../data/train.csv').sample(10000, random_state=23)
# Out:
# time: 1.1 s

# %%
for data in [train]:
    for col in ['question1', 'question2']:
        data[col][pd.isnull(data[col])] = ''
del data
# Out:
# time: 13.5 ms

# %%
assert 404290 == train.shape[0]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-188-2e1c73cae32c> in <module>()
# ----> 1 assert 404290 == train.shape[0]
#
# AssertionError:
# time: 8.69 ms

# %%
print(train.shape)
train.head(3)
# Out:
# (10000, 5)
#           qid1    qid2                                       question1  \
# id
# 237921    9732   79801             Is sex necessary in a relationship?
# 181001  277377  277378   What are the most inspiring start up stories?
# 294691  150129   93109  What is your best way to do digital marketing?
#
#                                                      question2  is_duplicate
# id
# 237921            Why is sex important in a good relationship?             1
# 181001           What are the most inspirational stories ever?             0
# 294691  What are the best unique ways to do Digital Marketing?             1
# time: 9.67 ms

# %%
train.tail(3)
# Out:
#           qid1    qid2  \
# id
# 165245  256635  256636
# 251754   69108   11477
# 130958   37405  210066
#
#                                                            question1  \
# id
# 165245  How much money does the author of an academic textbook earn?
# 251754                                How can I improve my speaking?
# 130958         What are some tips for having sex for the first time?
#
#                                            question2  is_duplicate
# id
# 165245  How much does it cost to publish a textbook?             0
# 251754                 I want to improve my English?             1
# 130958        What are some tips for first time sex?             1
# time: 9.33 ms

# %%
for col in ['question1', 'question2']:
    train[col] = train[col].apply(lambda x: nltk.word_tokenize( x.lower() ))
# Out:
# time: 2min 4s

# %%
STOP_WORDS = stopwords.words('english')

def remove_stopwords(tokenized_sent):
    unique_stopwords = set(STOP_WORDS)
    return [word for word in tokenized_sent if word.lower() not in unique_stopwords]


def concatenate_tokens(token_list):
    return str(' '.join(token_list))


def find_similarity(sent1, sent2):
    return SequenceMatcher(lambda x: x in (' ', '?', '.', '""', '!'), sent1, sent2).ratio()


def return_common_tokens(sent1, sent2):
    return " ".join([word.lower() for word in sent1 if word in sent2])


def convert_tokens_lower(tokens):
    return [token.lower() for token in tokens]
# Out:
# time: 10.8 ms

# %%
train_transformed = pd.DataFrame(index = train.index)
temp_features = pd.DataFrame()

for i in (1, 2):
    # question tokens
    train_transformed['question%s_tokens' % i] = train['question%s' % i].apply(nltk.word_tokenize)
    # question lowercase tokens
    train_transformed['question%s_lowercase_tokens' % i] = train_transformed['question%s_tokens' % i].apply(convert_tokens_lower)
    # question lowercase tokens join with ' '
    train_transformed['question%s_lowercase' % i] = train_transformed['question%s_lowercase_tokens' % i].apply(concatenate_tokens)
    # remove stop words from question tokens
    train_transformed['question%s_words' % i] = train_transformed['question%s_tokens' % i].apply(remove_stopwords)
    # w\o stop words join ' '
    train_transformed['question%s_pruned' % i] = train_transformed['question%s_words' % i].apply(concatenate_tokens)
# Out:
# time: 3.34 s

# %%
temp_features['common_tokens'] = np.vectorize(return_common_tokens)(
    train_transformed['question1_tokens'],
    train_transformed['question2_tokens'])

naive_similarity = pd.DataFrame()
naive_similarity['similarity'] = np.vectorize(find_similarity)(
    train['question1'], train['question2'])
naive_similarity['pruned_similarity'] = np.vectorize(find_similarity)(
    train_transformed['question1_pruned'], train_transformed['question2_pruned'])
# Out:
# time: 4.73 s

# %%
train.tail(3)
# Out:
#             id    qid1    qid2  \
# 165245  165245  256635  256636
# 251754  251754   69108   11477
# 130958  130958   37405  210066
#
#                                                            question1  \
# 165245  How much money does the author of an academic textbook earn?
# 251754                                How can I improve my speaking?
# 130958         What are some tips for having sex for the first time?
#
#                                            question2  is_duplicate
# 165245  How much does it cost to publish a textbook?             0
# 251754                 I want to improve my English?             1
# 130958        What are some tips for first time sex?             1
# time: 9.85 ms

# %%
dictionary = pd.DataFrame()

#Deriving the TF-IDF
dictionary['concatenated_questions'] = train['question1'] +\
                                       train['question2']

vectorizer = CountVectorizer()
terms_matrix = vectorizer.fit_transform(dictionary['concatenated_questions'])
terms_matrix_1 = vectorizer.transform(train['question1'])
terms_matrix_2 = vectorizer.transform(train['question2'])
common_terms_matrx = vectorizer.transform(temp_features['common_tokens'])

transformer = TfidfTransformer(smooth_idf = False)
weights_matrix = transformer.fit_transform(terms_matrix)
weights_matrix_1 = transformer.transform(terms_matrix_1)
weights_matrix_2 = transformer.transform(terms_matrix_2)
common_weights_matrix = transformer.transform(common_terms_matrx)

len(transformer.idf_), terms_matrix.shape
# Out:
# (15187, (10000, 15187))
# time: 765 ms

# %%
#Converting the sparse matrices into dataframes
transformed_matrix_1 = weights_matrix_1.tocoo(copy = False)
transformed_matrix_2 = weights_matrix_2.tocoo(copy = False)
transformed_common_weights_matrix = common_weights_matrix.tocoo(copy = False)

weights_dataframe_1 = pd.DataFrame({'index_': transformed_matrix_1.row,
                                    'term_id': transformed_matrix_1.col,
                                    'weight_q1': transformed_matrix_1.data}
                                   )[['index_', 'term_id', 'weight_q1']].sort_values(['index_', 'term_id']).reset_index(drop = True)
weights_dataframe_2 = pd.DataFrame({'index_': transformed_matrix_2.row,
                                    'term_id': transformed_matrix_2.col,
                                    'weight_q2': transformed_matrix_2.data}
                                   )[['index_', 'term_id', 'weight_q2']].sort_values(['index_', 'term_id']).reset_index(drop = True)
weights_dataframe_3 = pd.DataFrame({'index_': transformed_common_weights_matrix.row,
                                    'term_id': transformed_common_weights_matrix.col,
                                    'common_weight': transformed_common_weights_matrix.data}
                                   )[['index_', 'term_id', 'common_weight']].sort_values(['index_', 'term_id']).reset_index(drop = True)
# Out:
# time: 68.8 ms

# %%
weights_dataframe_1[weights_dataframe_1.index_ == 0]
# Out:
#    index_  term_id  weight_q1
# 0       0     6899   0.189101
# 1       0     7313   0.158552
# 2       0     9198   0.618865
# 3       0    11314   0.538469
# 4       0    12173   0.515906
# time: 9.63 ms

# %%
#Summing the weights of each token in each question to get the summed weight of the question
sum_weights_1 = weights_dataframe_1.groupby('index_').sum()
sum_weights_2 = weights_dataframe_2.groupby('index_').sum()
sum_weights_3 = weights_dataframe_3.groupby('index_').sum()

# Join by term id
weights = sum_weights_1.join(sum_weights_2, how = 'outer', lsuffix = '_q1',
                             rsuffix = '_q2').\
    join(sum_weights_3, how = 'outer', lsuffix = '_cw', rsuffix = '_cw')

weights = weights.fillna(0)
del weights['term_id_q1'], weights['term_id_q2'], weights['term_id']

print (weights[:20])
# Out:
#         weight_q1  weight_q2  common_weight
# index_
# 0        2.020893   2.438344       1.616312
# 1        2.485519   2.303256       1.917377
# 2        2.658949   2.735171       1.946522
# 3        2.737284   2.750768       1.406763
# 4        4.007998   4.007998       4.007998
# 5        3.447859   3.507630       3.252584
# 6        2.799849   2.004068       1.000000
# 7        3.085802   2.422342       0.000000
# 8        2.503914   2.142919       1.000000
# 9        1.993572   1.864838       1.599615
# 10       2.517155   2.439050       1.884600
# 11       2.539523   2.502484       1.763797
# 12       2.553175   2.678135       2.168378
# 13       2.808284   2.949881       1.569570
# 14       3.537830   3.624433       3.537830
# 15       3.434058   3.527817       2.012766
# 16       4.033230   3.174608       2.696729
# 17       3.523631   4.568617       2.141541
# 18       2.834307   3.805428       1.268429
# 19       2.618584   2.267223       2.169166
# time: 32.8 ms

# %%
#Creating a random train-test split
X = naive_similarity.join(weights, how = 'inner')
y = train['is_duplicate']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5, random_state = 42)

#Scaling the features
#sc = StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)


print (X_train[:20])

"""

We train our algorithm (gradient boosting classifier) and print the logarithmic loss:

#Training the algorithm and making a prediction"""

params = {'alpha': 0.1,
 'colsample_bytree': 0.7,
 'eta': 0.01,
 'eval_metric': 'logloss',
 'max_depth': 6,
 'min_child_weight': 25,
 'objective': 'binary:logistic',
 'seed': 42,
 'silent': 1,
 'subsample': 0.7}

num_rounds = 800 
plst = list(params.items())
sc = StandardScaler()
xgtrain = xgb.DMatrix(X_train, label=y_train)
xgtest = xgb.DMatrix(X_test)

model = xgb.train(plst, xgtrain, num_rounds, verbose_eval=50)
y_pred = model.predict(xgtest)
print ('The log loss is %s' % log_loss(y_test, y_pred))

prediction = pd.DataFrame(y_pred, columns = ['is_duplicate'], index = X_test.index)

"""
#Training the algorithm and making a prediction
gbc = GradientBoostingClassifier(n_estimators = 8000, learning_rate = 0.3, max_depth = 3)
gbc.fit(X_train, y_train.values.ravel())
prediction = pd.DataFrame(gbc.predict(X_test), columns = ['is_duplicate'], index = X_test.index)

#Inspecting our mistakes
prediction_actual = prediction.join(y_test, how = 'inner', lsuffix = '_predicted', rsuffix = '_actual').join(train[['question1', 'question2']], how = 'inner').join(X_test, how = 'inner')
print ('The log loss is SCKL %s' % log_loss(y_test, prediction))
"""
0
# Out:
#       similarity  pruned_similarity  weight_q1  weight_q2  common_weight
# 7660    0.727273           0.682927   2.096303   2.017127       1.383557
# 275     0.680000           0.730159   2.433464   2.867656       1.757610
# 2985    0.875000           0.804348   2.722076   2.776350       2.590012
# 5646    0.388060           0.356436   3.061119   3.254577       1.587374
# 5849    0.377358           0.363636   2.937788   3.559681       1.655746
# 3477    0.327684           0.292308   3.909865   3.748374       2.143320
# 7558    0.722892           0.707692   2.252590   2.348782       2.022280
# 3558    0.682927           0.727273   2.710025   2.306698       1.866726
# 2809    0.625000           0.666667   2.717055   2.665511       2.100895
# 9113    0.540000           0.459016   2.584222   2.298426       1.572971
# 4861    0.240310           0.372881   3.787417   4.400992       1.942285
# 6586    0.494118           0.654545   3.005096   4.065321       2.197647
# 3416    0.250000           0.267717   2.659246   3.965137       1.000000
# 307     0.594059           0.714286   2.868053   2.609235       1.988029
# 3908    0.605263           0.530612   2.322582   2.297558       2.007951
# 348     0.359281           0.355140   3.275279   3.512155       1.827330
# 826     0.741573           0.666667   2.824722   2.328368       2.328368
# 9501    0.636364           0.592593   2.099759   2.087210       1.626096
# 4482    0.838710           0.925373   2.623933   2.483407       2.126613
# 6576    0.210526           0.075000   2.708754   2.007376       1.000000
# The log loss is 0.511018685765
# 0
# time: 1.51 s

# %%
prediction_actual = prediction.join(y_test, how = 'inner',
                                    lsuffix = '_predicted',
                                    rsuffix = '_actual').\
    join(train[['question1', 'question2']], how = 'inner').\
    join(train_transformed, how = 'inner').\
    join(X_test, how = 'inner')
    
bind = (prediction_actual.is_duplicate_actual == 0) & (prediction_actual.is_duplicate_predicted>0.6)

bind = (prediction_actual.is_duplicate_actual == 1) & (prediction_actual.is_duplicate_predicted < 0.6)
print(np.sum(bind), X_test.shape)
prediction_actual[bind]
# Out:
# 17 (5000, 5)
#       is_duplicate_predicted  is_duplicate_actual  \
# 2304                0.459989                    1
# 6603                0.346490                    1
# 532                 0.208236                    1
# 1683                0.020531                    1
# 7444                0.230187                    1
# 7578                0.558460                    1
# 8204                0.565860                    1
# 8383                0.538299                    1
# 1272                0.484915                    1
# 8641                0.337970                    1
# 9636                0.019978                    1
# 5261                0.156624                    1
# 5022                0.046069                    1
# 51                  0.244072                    1
# 1983                0.012955                    1
# 1164                0.090035                    1
# 2306                0.446241                    1
#
#                                                                                                                               question1  \
# 2304                                  What might cause a brown discharge during the menstrual cycle (before/during/after menstruation)?
# 6603                                                                                  Why are 500 and 1000 notes being banned in India?
# 532                                                                                                      How imminent is world war III?
# 1683                                                                             What is the best app for Berlin public transportation?
# 7444  Can we kill herpes virus once it is out of nerve cell I attached a pic of the description of the question please read and answer?
# 7578                                                                                               What should I know to get into GSoC?
# 8204                                                                                                     Why should I learn C language?
# 8383                                                                                                              How do I lose weight?
# 1272                                                                 Why does magnetic field produce when current flows in a conductor?
# 8641                                                                                             What do you want more of in your life?
# 9636                                                                                       What is your favorite music video clip? Why?
# 5261                                                            How can changing 500 and 1000 rupee notes end the black money in India?
# 5022                                                                                What should I do to get into an Ivy League college?
# 51                                                                             Will a Blu Ray play on a regular DVD player? If so, how?
# 1983                                                                                                          How did Donald trump win?
# 1164                                                                                    What can one do to relieve severe chronic pain?
# 2306                                                                          What skills do all successful salespeople have in common?
#
#                                                                                   question2  \
# 2304                              Why do I get a brown discharge before my menstrual cycle?
# 6603                      What are the reasons why eradication of 1000 rs and 500 rs notes?
# 532                                                      Are we heading toward World War 3?
# 1683                     What are the best public transportation apps to help me in Berlin?
# 7444                                Can we kill herpes virus once it is out of nerves cell?
# 7578             What do I need to learn to get a fair chance of getting selected for GSoC?
# 8204                                                                      Should I learn C?
# 8383                                                       What can I do to lose 20 pounds?
# 1272               Why is a magnetic field produced when current flows through a conductor?
# 8641                                                              What do you want in life?
# 9636                                          What are your favorite music and video clips?
# 5261                                 How banning 500 and 1000 rupee can affect black money?
# 5022  I know this is a dumb question, but how do I get admitted into an Ivy League college?
# 51                                  How can you play a Blu Ray DVD on a regular DVD player?
# 1983                       How did Donald Trump win despite projections that he would fail?
# 1164                                  What has worked for you to help relieve chronic pain?
# 2306                  What personality traits do all successful salespeople have in common?
#
#                                                                                                                                                     question1_tokens  \
# 2304                                            [What, might, cause, a, brown, discharge, during, the, menstrual, cycle, (, before/during/after, menstruation, ), ?]
# 6603                                                                                                  [Why, are, 500, and, 1000, notes, being, banned, in, India, ?]
# 532                                                                                                                          [How, imminent, is, world, war, III, ?]
# 1683                                                                                              [What, is, the, best, app, for, Berlin, public, transportation, ?]
# 7444  [Can, we, kill, herpes, virus, once, it, is, out, of, nerve, cell, I, attached, a, pic, of, the, description, of, the, question, please, read, and, answer, ?]
# 7578                                                                                                                 [What, should, I, know, to, get, into, GSoC, ?]
# 8204                                                                                                                         [Why, should, I, learn, C, language, ?]
# 8383                                                                                                                                   [How, do, I, lose, weight, ?]
# 1272                                                                                [Why, does, magnetic, field, produce, when, current, flows, in, a, conductor, ?]
# 8641                                                                                                              [What, do, you, want, more, of, in, your, life, ?]
# 9636                                                                                                       [What, is, your, favorite, music, video, clip, ?, Why, ?]
# 5261                                                                        [How, can, changing, 500, and, 1000, rupee, notes, end, the, black, money, in, India, ?]
# 5022                                                                                               [What, should, I, do, to, get, into, an, Ivy, League, college, ?]
# 51                                                                                      [Will, a, Blu, Ray, play, on, a, regular, DVD, player, ?, If, so, ,, how, ?]
# 1983                                                                                                                               [How, did, Donald, trump, win, ?]
# 1164                                                                                                     [What, can, one, do, to, relieve, severe, chronic, pain, ?]
# 2306                                                                                           [What, skills, do, all, successful, salespeople, have, in, common, ?]
#
#                                                                                                                                           question1_lowercase_tokens  \
# 2304                                            [what, might, cause, a, brown, discharge, during, the, menstrual, cycle, (, before/during/after, menstruation, ), ?]
# 6603                                                                                                  [why, are, 500, and, 1000, notes, being, banned, in, india, ?]
# 532                                                                                                                          [how, imminent, is, world, war, iii, ?]
# 1683                                                                                              [what, is, the, best, app, for, berlin, public, transportation, ?]
# 7444  [can, we, kill, herpes, virus, once, it, is, out, of, nerve, cell, i, attached, a, pic, of, the, description, of, the, question, please, read, and, answer, ?]
# 7578                                                                                                                 [what, should, i, know, to, get, into, gsoc, ?]
# 8204                                                                                                                         [why, should, i, learn, c, language, ?]
# 8383                                                                                                                                   [how, do, i, lose, weight, ?]
# 1272                                                                                [why, does, magnetic, field, produce, when, current, flows, in, a, conductor, ?]
# 8641                                                                                                              [what, do, you, want, more, of, in, your, life, ?]
# 9636                                                                                                       [what, is, your, favorite, music, video, clip, ?, why, ?]
# 5261                                                                        [how, can, changing, 500, and, 1000, rupee, notes, end, the, black, money, in, india, ?]
# 5022                                                                                               [what, should, i, do, to, get, into, an, ivy, league, college, ?]
# 51                                                                                      [will, a, blu, ray, play, on, a, regular, dvd, player, ?, if, so, ,, how, ?]
# 1983                                                                                                                               [how, did, donald, trump, win, ?]
# 1164                                                                                                     [what, can, one, do, to, relieve, severe, chronic, pain, ?]
# 2306                                                                                           [what, skills, do, all, successful, salespeople, have, in, common, ?]
#
#                                                                                                                      question1_lowercase  \
# 2304                                what might cause a brown discharge during the menstrual cycle ( before/during/after menstruation ) ?
# 6603                                                                                  why are 500 and 1000 notes being banned in india ?
# 532                                                                                                      how imminent is world war iii ?
# 1683                                                                             what is the best app for berlin public transportation ?
# 7444  can we kill herpes virus once it is out of nerve cell i attached a pic of the description of the question please read and answer ?
# 7578                                                                                               what should i know to get into gsoc ?
# 8204                                                                                                     why should i learn c language ?
# 8383                                                                                                              how do i lose weight ?
# 1272                                                                 why does magnetic field produce when current flows in a conductor ?
# 8641                                                                                             what do you want more of in your life ?
# 9636                                                                                      what is your favorite music video clip ? why ?
# 5261                                                            how can changing 500 and 1000 rupee notes end the black money in india ?
# 5022                                                                                what should i do to get into an ivy league college ?
# 51                                                                           will a blu ray play on a regular dvd player ? if so , how ?
# 1983                                                                                                          how did donald trump win ?
# 1164                                                                                    what can one do to relieve severe chronic pain ?
# 2306                                                                          what skills do all successful salespeople have in common ?
#
#                                                                                         question1_words  \
# 2304     [might, cause, brown, discharge, menstrual, cycle, (, before/during/after, menstruation, ), ?]
# 6603                                                               [500, 1000, notes, banned, India, ?]
# 532                                                                      [imminent, world, war, III, ?]
# 1683                                                     [best, app, Berlin, public, transportation, ?]
# 7444  [kill, herpes, virus, nerve, cell, attached, pic, description, question, please, read, answer, ?]
# 7578                                                                               [know, get, GSoC, ?]
# 8204                                                                            [learn, C, language, ?]
# 8383                                                                                  [lose, weight, ?]
# 1272                                           [magnetic, field, produce, current, flows, conductor, ?]
# 8641                                                                                    [want, life, ?]
# 9636                                                               [favorite, music, video, clip, ?, ?]
# 5261                                   [changing, 500, 1000, rupee, notes, end, black, money, India, ?]
# 5022                                                                     [get, Ivy, League, college, ?]
# 51                                                      [Blu, Ray, play, regular, DVD, player, ?, ,, ?]
# 1983                                                                            [Donald, trump, win, ?]
# 1164                                                           [one, relieve, severe, chronic, pain, ?]
# 2306                                                       [skills, successful, salespeople, common, ?]
#
#                                                                          question1_pruned  \
# 2304   might cause brown discharge menstrual cycle ( before/during/after menstruation ) ?
# 6603                                                        500 1000 notes banned India ?
# 532                                                              imminent world war III ?
# 1683                                              best app Berlin public transportation ?
# 7444  kill herpes virus nerve cell attached pic description question please read answer ?
# 7578                                                                      know get GSoC ?
# 8204                                                                   learn C language ?
# 8383                                                                        lose weight ?
# 1272                                     magnetic field produce current flows conductor ?
# 8641                                                                          want life ?
# 9636                                                        favorite music video clip ? ?
# 5261                                changing 500 1000 rupee notes end black money India ?
# 5022                                                             get Ivy League college ?
# 51                                                  Blu Ray play regular DVD player ? , ?
# 1983                                                                   Donald trump win ?
# 1164                                                    one relieve severe chronic pain ?
# 2306                                               skills successful salespeople common ?
#
#                                                                                                   question2_tokens  \
# 2304                                       [Why, do, I, get, a, brown, discharge, before, my, menstrual, cycle, ?]
# 6603                             [What, are, the, reasons, why, eradication, of, 1000, rs, and, 500, rs, notes, ?]
# 532                                                                   [Are, we, heading, toward, World, War, 3, ?]
# 1683                             [What, are, the, best, public, transportation, apps, to, help, me, in, Berlin, ?]
# 7444                                        [Can, we, kill, herpes, virus, once, it, is, out, of, nerves, cell, ?]
# 7578                 [What, do, I, need, to, learn, to, get, a, fair, chance, of, getting, selected, for, GSoC, ?]
# 8204                                                                                      [Should, I, learn, C, ?]
# 8383                                                                   [What, can, I, do, to, lose, 20, pounds, ?]
# 1272                       [Why, is, a, magnetic, field, produced, when, current, flows, through, a, conductor, ?]
# 8641                                                                            [What, do, you, want, in, life, ?]
# 9636                                                      [What, are, your, favorite, music, and, video, clips, ?]
# 5261                                           [How, banning, 500, and, 1000, rupee, can, affect, black, money, ?]
# 5022  [I, know, this, is, a, dumb, question, ,, but, how, do, I, get, admitted, into, an, Ivy, League, college, ?]
# 51                                         [How, can, you, play, a, Blu, Ray, DVD, on, a, regular, DVD, player, ?]
# 1983                                [How, did, Donald, Trump, win, despite, projections, that, he, would, fail, ?]
# 1164                                            [What, has, worked, for, you, to, help, relieve, chronic, pain, ?]
# 2306                            [What, personality, traits, do, all, successful, salespeople, have, in, common, ?]
#
#                                                                                         question2_lowercase_tokens  \
# 2304                                       [why, do, i, get, a, brown, discharge, before, my, menstrual, cycle, ?]
# 6603                             [what, are, the, reasons, why, eradication, of, 1000, rs, and, 500, rs, notes, ?]
# 532                                                                   [are, we, heading, toward, world, war, 3, ?]
# 1683                             [what, are, the, best, public, transportation, apps, to, help, me, in, berlin, ?]
# 7444                                        [can, we, kill, herpes, virus, once, it, is, out, of, nerves, cell, ?]
# 7578                 [what, do, i, need, to, learn, to, get, a, fair, chance, of, getting, selected, for, gsoc, ?]
# 8204                                                                                      [should, i, learn, c, ?]
# 8383                                                                   [what, can, i, do, to, lose, 20, pounds, ?]
# 1272                       [why, is, a, magnetic, field, produced, when, current, flows, through, a, conductor, ?]
# 8641                                                                            [what, do, you, want, in, life, ?]
# 9636                                                      [what, are, your, favorite, music, and, video, clips, ?]
# 5261                                           [how, banning, 500, and, 1000, rupee, can, affect, black, money, ?]
# 5022  [i, know, this, is, a, dumb, question, ,, but, how, do, i, get, admitted, into, an, ivy, league, college, ?]
# 51                                         [how, can, you, play, a, blu, ray, dvd, on, a, regular, dvd, player, ?]
# 1983                                [how, did, donald, trump, win, despite, projections, that, he, would, fail, ?]
# 1164                                            [what, has, worked, for, you, to, help, relieve, chronic, pain, ?]
# 2306                            [what, personality, traits, do, all, successful, salespeople, have, in, common, ?]
#
#                                                                           question2_lowercase  \
# 2304                               why do i get a brown discharge before my menstrual cycle ?
# 6603                       what are the reasons why eradication of 1000 rs and 500 rs notes ?
# 532                                                       are we heading toward world war 3 ?
# 1683                      what are the best public transportation apps to help me in berlin ?
# 7444                                 can we kill herpes virus once it is out of nerves cell ?
# 7578              what do i need to learn to get a fair chance of getting selected for gsoc ?
# 8204                                                                       should i learn c ?
# 8383                                                        what can i do to lose 20 pounds ?
# 1272                why is a magnetic field produced when current flows through a conductor ?
# 8641                                                               what do you want in life ?
# 9636                                           what are your favorite music and video clips ?
# 5261                                  how banning 500 and 1000 rupee can affect black money ?
# 5022  i know this is a dumb question , but how do i get admitted into an ivy league college ?
# 51                                   how can you play a blu ray dvd on a regular dvd player ?
# 1983                        how did donald trump win despite projections that he would fail ?
# 1164                                   what has worked for you to help relieve chronic pain ?
# 2306                   what personality traits do all successful salespeople have in common ?
#
#                                                         question2_words  \
# 2304                       [get, brown, discharge, menstrual, cycle, ?]
# 6603                [reasons, eradication, 1000, rs, 500, rs, notes, ?]
# 532                                 [heading, toward, World, War, 3, ?]
# 1683              [best, public, transportation, apps, help, Berlin, ?]
# 7444                             [kill, herpes, virus, nerves, cell, ?]
# 7578       [need, learn, get, fair, chance, getting, selected, GSoC, ?]
# 8204                                                      [learn, C, ?]
# 8383                                              [lose, 20, pounds, ?]
# 1272          [magnetic, field, produced, current, flows, conductor, ?]
# 8641                                                    [want, life, ?]
# 9636                                 [favorite, music, video, clips, ?]
# 5261               [banning, 500, 1000, rupee, affect, black, money, ?]
# 5022  [know, dumb, question, ,, get, admitted, Ivy, League, college, ?]
# 51                       [play, Blu, Ray, DVD, regular, DVD, player, ?]
# 1983         [Donald, Trump, win, despite, projections, would, fail, ?]
# 1164                          [worked, help, relieve, chronic, pain, ?]
# 2306          [personality, traits, successful, salespeople, common, ?]
#
#                                             question2_pruned  similarity  \
# 2304                   get brown discharge menstrual cycle ?    0.850467
# 6603              reasons eradication 1000 rs 500 rs notes ?    0.507937
# 532                             heading toward World War 3 ?    0.451613
# 1683           best public transportation apps help Berlin ?    0.237288
# 7444                         kill herpes virus nerves cell ?    0.361809
# 7578      need learn get fair chance getting selected GSoC ?    0.842105
# 8204                                               learn C ?    0.468750
# 8383                                        lose 20 pounds ?    0.876712
# 1272       magnetic field produced current flows conductor ?    0.507692
# 8641                                             want life ?    0.620690
# 9636                            favorite music video clips ?    0.156425
# 5261             banning 500 1000 rupee affect black money ?    0.571429
# 5022  know dumb question , get admitted Ivy League college ?    0.312195
# 51                     play Blu Ray DVD regular DVD player ?    0.424242
# 1983       Donald Trump win despite projections would fail ?    0.149533
# 1164                      worked help relieve chronic pain ?    0.354839
# 2306      personality traits successful salespeople common ?    0.615385
#
#       pruned_similarity  weight_q1  weight_q2  common_weight
# 2304           0.864516   4.137393   3.693397       3.582522
# 6603           0.437500   2.704007   2.240851       1.826248
# 532            0.540541   2.298379   1.739305       1.000000
# 1683           0.235294   3.177638   2.750046       1.357952
# 7444           0.373134   3.114752   3.919180       2.240640
# 7578           0.871795   1.849544   1.672630       1.192016
# 8204           0.564103   3.253949   2.968196       2.021113
# 8383           0.727273   2.172359   2.200785       2.065846
# 1272           0.474227   3.319158   2.747890       2.220099
# 8641           0.684211   1.659821   2.177453       1.519794
# 9636           0.150000   4.286586   2.190757       0.000000
# 5261           0.440000   2.262776   2.284017       1.000000
# 5022           0.348993   2.766099   2.988142       1.315945
# 51             0.395349   2.696284   2.963961       1.794358
# 1983           0.236842   2.754914   3.186115       0.000000
# 1164           0.449438   2.249510   3.434585       1.409066
# 2306           0.650000   2.305477   1.863444       1.572985
# time: 150 ms
